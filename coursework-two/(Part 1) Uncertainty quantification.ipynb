# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.distributions as dist
import torch.nn as nn

# %matplotlib inline

# %% [markdown]
# # Stochastic gradient Langevin dynamics, and uncertainty quantification
#
# In this first part of the coursework you'll do two things:
#
# * Implement stochastic gradient Langevin dynamics for sampling from a Bayesian neural network
# * Break down the variance to estimate epistemic and aleatoric uncertainty
#
# We're going to run this on the following toy 2D dataset, consisting of **two moons**, each a different class.

# %%
dataset, validation_set = torch.load("two_moons.pt")
X_train, y_train = dataset.tensors
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.xlim(-3,3)
plt.ylim(-2,2)
plt.show()

# %% [markdown]
# ## We'll use the following simple feedforward network.

# %%
class TwoMoonsNetwork(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(2, 100),
                        nn.ReLU(), 
                        nn.Linear(100, 10),
                        nn.ReLU(),
                        nn.Linear(10, 1))
        
    def forward(self, x):
        h = self.net(x)
        return torch.sigmoid(h).squeeze(1)
    
network = TwoMoonsNetwork()

# %% [markdown]
# # TASK 1 (5 points): Define the likelihood and the prior
#
# Let $x_i \in \mathbb{R}^2$ denote an input, $y_i \in \{ 0, 1\}$ a target, and $\theta$ the network parameters.
#
# Let $\hat y_i = f_\theta(x_i)$ denote the output of the network $f_\theta$.
#
# You need to define:
#
# * `log_likelihood`, evaluating a Bernoulli distribution $$\log p(y|x, \theta) = \log \mathrm{Bernoulli}(y | f_\theta(x));$$
# * `log_prior`, evaluating a standard normal distribution $$\log p(\theta) = \log \mathcal{N}(\theta | 0, I).$$
#
# Both of these functions should return a numeric scalar value.
#
# For the prior, you will need to somehow access the parameters of the network! There are several ways of doing this. I suggest looking at the pytorch documentation for either
#
# * iterating through `network.parameters()`, or
# * using helper functions such as `nn.utils.parameters_to_vector`

# %%
def log_likelihood(network, X, y):
    """
    This function computes the log probability `log p(y | x, theta)`
    for a batch of inputs X.
    
    INPUT:
    network : instance of classifier network, extends `nn.Module`
    X       : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y       : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    
    OUTPUT:
    lp      : log probability value of log p(y | x, theta); scalar
    
    """
    # YOUR CODE HERE
    lp = dist.Bernoulli(probs = network(X)).log_prob(y).sum(0)
    return lp

# %%
# grading

# %%
def log_prior(network):
    # YOUR CODE HERE
    weights = nn.utils.parameters_to_vector(network.parameters())
    logprior = dist.Normal(0, 1).log_prob(weights).sum(0)
    return logprior

# %%
# grading

# %%
# grading

# %% [markdown]
# # TASK 2 (3 points): Minibatching
#
# Minibatching is "trickier" when we have a prior on the network parameters.
#
# The function `log_joint_minibatch` should return a mini-batch estimate of the log joint of the full data, i.e. returning an estimator of $$\log p(\theta) + \sum_{i=1}^N \log p(y_i | x_i, \theta)$$ but which is evaluated on only the specified subset of the $N$ data points.

# %%
def log_joint_minibatch(network, X_batch, y_batch, N_training):
    """ Return a minibatch estimate of the full log joint probability 
    
    INPUT:
    network    : instance of classifier network, extends `nn.Module`
    X_batch    : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y_batch    : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    N_training : total number of training data instances in the full training set

    OUTPUT:
    lp : return an estimate of log p(y, theta | X), as computed on the batch; scalar.

    """
    # YOUR CODE HERE

    #Definded logprior using the function made above
    logprior = log_prior(network)

    #Defined log liklihood using the function made above
    loglikelihood_batch = log_likelihood(network, X_batch, y_batch)
    #Calculate scaled minibatch liklihood estimate
    scaled_likelihood = (N_training / X_batch.size(0)) * loglikelihood_batch
    
    #Calculate log joint
    logjoint = logprior + scaled_likelihood

    return logjoint

# %%
# grading

# %%
# grading

# %% [markdown]
# ## Self-diagnostic
#
# This is a small-enough dataset that we can compute the log joint probability on the whole dataset:

# %%
with torch.no_grad():
    full_data_lp = log_prior(network) + log_likelihood(network, X_train, y_train)
print("Full data log probability: %0.4f" % full_data_lp.item())
# Out:
# Full data log probability: -1325.7891

# %% [markdown]
# ### In the next cell, we call `log_joint_minibatch`.
#
# If all the code is working correctly, the minibatch estimates should be roughly normally-distributed around the true value!
#
# Changing the batch size should not change the mean of this distribution. Try running the cell below several times.
#
# If the histogram is far away from the true value (the black vertical dashed line), then you probably have a bug.

# %%
dataloader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=5)

with torch.no_grad():
    batch_lp_est = [log_joint_minibatch(network, X, y, len(dataset)).item() for X, y in dataloader]
plt.hist(batch_lp_est, bins=10);
yl = plt.ylim()
plt.plot(full_data_lp.item()*np.ones(2), [0, plt.ylim()[1]], 'k--')
plt.ylim(yl);
# torch.stack(batch_lp_est).sum()
plt.show()

# %% [markdown]
# ## Train the model (MAP estimation)
#
# Run the following cell to train your model, to find a MAP estimate.

# %%
dataloader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=5)
opt = torch.optim.Adam(network.parameters())

N_epochs = 400
train_lp = []

for epoch in range(N_epochs):
    for X, y in dataloader:
        opt.zero_grad()
        loss = -log_joint_minibatch(network, X, y, len(dataset))
        loss.backward()
        opt.step()
    with torch.no_grad():
        train_lp.append((log_likelihood(network, X_train, y_train) + log_prior(network)).item())
plt.plot(train_lp)
plt.xlabel("epoch")
plt.ylabel("$p(y, \\theta | x)$");
plt.show()

# %% [markdown]
# ## Confidence plot
#
# To visualize the result, we'll look at a *confidence plot*.
#
# The *confidence* is the probability assigned to whichever class is predicted.
#
# If the most likely class is "yellow", then it shows $p(y = \text{yellow})$. If the most likely class is red, it shows $p(y = \text{red})$.

# %%
XX, YY = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-2, 2, 100))
with torch.no_grad():
    py = network(torch.FloatTensor(np.stack((XX.ravel(), YY.ravel())).T))
    conf = torch.where(py > 0.5, py, 1-py) ## THIS LINE COMPUTES THE CONFIDENCE
    ZZ = conf.reshape(XX.shape)
CS = plt.contourf(XX, YY, ZZ, cmap='Blues', vmin=0.5, vmax=1.2)
plt.colorbar(ticks=np.linspace(0.5, 1, 6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k')
plt.title("Confidence plot");
plt.show()

# %% [markdown]
# # Calibration and reliability diagrams
#
# I've implemented a reliability diagram plot and expected calibration error computation here.
#
# Could be interesting to see how the number of bins affects the result…!

# %%
def reliability_diagram(y, y_hat, N_bins=10):
    """
    Plot a reliability diagram
    """
    bins = torch.linspace(0, 1, N_bins+1)
    which_bin = (y_hat[:,None] >= bins[1:]).long().sum(-1).numpy()
    freq = [y[which_bin==k].mean().item() for k in range(N_bins)]
    conf = [y_hat[which_bin==k].mean().item() for k in range(N_bins)]
    plt.bar(bins[1]/2+np.arange(N_bins)/N_bins, freq, width=bins[1]*.9);
    plt.plot(conf, freq, 'o-', color='k')
    plt.plot([0, 1], [0, 1], '--', color='#333');

def expected_calibration_error(y, y_hat, N_bins=10):
    """
    Compute the expected calibration error
    """
    bins = torch.linspace(0, 1, N_bins+1)
    which_bin = (y_hat[:,None] >= bins[1:]).long().sum(-1).numpy()
    counts = []
    acc = []
    conf = []
    for k in range(N_bins):
        count = len(y[which_bin==k])
        if count > 0:
            acc.append(y[which_bin==k].mean().item())
            conf.append(y_hat[which_bin==k].mean().item())
        else:
            acc.append(0.0)
            conf.append(0.0)
        counts.append(count)
    return ((np.abs(np.array(acc) - np.array(conf))*np.array(counts))/len(y)).sum()

# %%
with torch.no_grad():
    y_hat = network(validation_set.tensors[0])

reliability_diagram(y=validation_set.tensors[1], y_hat=y_hat)
print("ECE = %0.4f" % expected_calibration_error(validation_set.tensors[1], y_hat))
plt.title("Reliability diagram");
plt.show()
# Out:
# ECE = 0.0435

# %% [markdown]
# # TASK 3 (6 points): stochastic gradient Langevin dynamics (SGLD)
#
# In this task you can get
#
# * 3 points for implementing the SGLD MCMC update
# * 3 points for implementing Monte Carlo prediction
#
# The `SGLD_step` function below should take a current set of network parameters $\theta$, and update them as
#
# $$\theta' = \theta + \frac{\epsilon^2}{2} \nabla_\theta \log p(\theta, y | X) + \epsilon z$$
#
# where $\epsilon$ is a learning rate, $X, y$ are a current mini-batch, and $z \sim \mathcal{N}(0, I)$ and has the same dimensionality as $\theta$.
#
# For more details see the week 7 lecture slides!
#
# Note that you will actually have to **do the update**. The following function does not return anything! Instead, it updates the parameters of the network, similar to how a `torch.optim` optimizer updates the parameters.

# %%
def SGLD_step(network, X, y, N_training, epsilon):
    """
    Run one step of SGLD given a mini-batch, and update the parameters of the network.
    
    INPUT:
    network    : instance of classifier network, extends `nn.Module`
    X_batch    : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y_batch    : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    N_training : total number of training data instances in the full training set
    epsilon    : step size / learning rate parameters (scalar)
    """
    # YOUR CODE HERE

    network.zero_grad()  # Clear previous gradients
    log_joint_minibatch_est = log_joint_minibatch(network, X, y, N_training)  # Compute log joint
    log_joint_minibatch_est.backward()  # Backpropagate gradients

    with torch.no_grad():
        for params in network.parameters():
            noise_variable = torch.randn_like(params)  # Sample noise with the same shape as params
            params += 0.5 * (epsilon ** 2) * params.grad + epsilon * noise_variable  # Update params

# %%
# grading

# %%
# grading

# %% [markdown]
# ### Cyclic learning rate
#
# We're going to use a cyclic learning rate schedule for $\epsilon$, like discussed in the lectures. That function is pre-written, below.

# %%
def learning_rate_schedule(N_steps, N_samples, epsilon):
    """
    Pre-compute a learning-rate schedule for SGLD.
    
    INPUT:
    N_steps   : number of SGD updates between each "reset"
    N_samples : number of times we reach the lowest target learning rate
    epsilon   : base learning rate
    
    OUTPUT:
    epsilon_t : vector of length N_steps*N_samples, containing epsilon_t at each iteration t
    """
    return epsilon * (np.cos(np.pi * (np.arange(N_samples*N_steps) % N_steps)/N_steps) + 1)

plt.plot(learning_rate_schedule(N_steps=100, N_samples=10, epsilon=0.5));
plt.xlabel("iteration");
plt.ylabel("epsilon");
plt.show()

# %% [markdown]
# ### Running the sampler
# The following function is also given: it will actually run the SGLD sampler, by calling your `SGLD_step` function above.

# %%
def draw_sgld_samples(network, N_samples, N_steps_per_sample, base_epsilon=0.02):
    """
    Draw samples using SGLD, following a prescribed learning rate schedule
    
    OUTPUT:
    samples : torch.FloatTensor, shape = (N_samples, "# of parameters in network")
    """
    lr_schedule = learning_rate_schedule(N_steps_per_sample, N_samples, base_epsilon)
    samples = []
    step = 0
    while True:
        for X, y in dataloader:
            SGLD_step(network, X, y, len(dataset), epsilon=lr_schedule[step])
            step += 1
            if step % N_steps_per_sample == 0:
                samples.append(nn.utils.parameters_to_vector(network.parameters()).detach())
            if step == len(lr_schedule):
                return torch.stack(samples)

# %%
samples = draw_sgld_samples(network, N_samples=50, N_steps_per_sample=200)
print("Tensor holding samples of theta has shape:", samples.shape)
# Out:
# Tensor holding samples of theta has shape: torch.Size([50, 1321])

# %% [markdown]
# ## Making predictions
#
# After running the sampler, you now have a `torch.FloatTensor` which contains many different sampled versions of the network parameters $s = 1,\dots,S$.
#
# To make predictions on an input batch $X$, you will somehow need to "load" in the stored parameters, and run the forward pass using different $\theta^{(s)}$.

# %%
def predict_from_samples(X, network, samples):
    """
    
    INPUT:
    X       : batch of input points at which to make predictions; shape = (batch_size, 2)
    network : instance of classifier network, extends `nn.Module`
    samples : torch.FloatTensor containing samples of theta; shape = (num_samples, "# of parameters in network")
    
    OUTPUT:
    y_hat_samples : torch.FloatTensor containing samples of y_hat; shape = (num_samples, batch_size)
    """
    # YOUR CODE HERE
    predictions = [] 
    #Iterate over parameter sample
    for sample in samples:
        #Load paramters in the network
        nn.utils.vector_to_parameters(sample, network.parameters())
        #Find predictions for the batch
        predictions.append(network(X).detach())
        
    return torch.stack(predictions)

# %%
# The following should be true if your code is working!
assert predict_from_samples(X_train, network, samples).shape == (samples.shape[0], X_train.shape[0])

# %%
# grading

# %%
# grading

# %% [markdown]
# ## Confidence plot and reliability diagrams for the Bayesian classifier

# %%
XX, YY = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-2, 2, 100))
with torch.no_grad():
    XXYY = torch.FloatTensor(np.stack((XX.ravel(), YY.ravel())).T)
    out = predict_from_samples(XXYY, network, samples)
    py = out.mean(0)
    conf = torch.where(py > 0.5, py, 1-py)
    ZZ = conf.reshape(XX.shape)
CS = plt.contourf(XX, YY, ZZ, cmap='Blues', vmin=0.5, vmax=1.2)
plt.colorbar(ticks=np.linspace(0.5, 1, 6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.title("Confidence plot");
plt.show()

# %%
with torch.no_grad():
    y_hat = predict_from_samples(validation_set.tensors[0], network, samples).mean(0)

reliability_diagram(y=validation_set.tensors[1], y_hat=y_hat)
print("ECE = %0.4f" % expected_calibration_error(validation_set.tensors[1], y_hat))

plt.title("Reliability diagram");
plt.show()
# Out:
# ECE = 0.0464

# %% [markdown]
# ## Uncertainty quantification
#
# We can measure the uncertainty in our predictor by looking at the variance of the predictive distribution
#
# $$p(y | \hat y).$$
#
# Here, $\hat y$ is the posterior mean: the average $p(y = 1)$ estimated across all posterior samples.
#
# The total predictive variance of $y$ is the variance of this distribution, i.e.
#
# $$Var [ y | x ] = Var \left [ \int p(y | x, \theta)p(\theta | \mathcal{D}) d\theta \right]$$
#
# One way to estimate epistemic and aleatoric uncertainty is to look at the variance of $\hat y$, i.e. the variance in $f_\theta(x)$ under the posterior over $\theta$. This corresponds to epistemic uncertainty. The difference between these two is then roughly the aleatoric uncertainty.
#
# There are probably better ways to compute (and explain!) this, but hopefully the following plots look clear.

# %%
# Variance of predictive distribution over y
var_of_prediction = dist.Bernoulli(out.mean(0)).variance

# Epistemic uncertainty: Variance across values of y_hat
var_of_mean = out.var(0)

# %% [markdown]
# ### Darker colors are more uncertain:

# %%
plt.title("All uncertainty ($Var[y | x]$)")
plt.contourf(XX, YY, var_of_prediction.reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.3)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
# - torch.sigmoid(out).var(0).reshape(XX.shape))
plt.show()

# %%
plt.title("Epistemic uncertainty only")
plt.contourf(XX, YY, var_of_mean.reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.28)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.show()

# %%
plt.title("Aleatoric uncertainty only")
plt.contourf(XX, YY, (var_of_prediction - var_of_mean).reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.3)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.show()

# %% [markdown]
# # TASK 4 (up to 5 points, free response): Interpretation
#
# Take a look at Figure 1 in the paper https://arxiv.org/pdf/2002.10118.pdf, "Being Bayesian, Even Just a Bit, Fixes Overconfidence in ReLU Networks", Kristiadi et al. 2020.
#
# 1. (4 points) Qualitatively, the uncertainty in figure 1 probably looks quite different from your plots in this notebook. Try to give two different reasons for why the results here might be different.
# 2. (1 point) What is going on with calibration / temperature scaling? Why doesn't the temperature scaling help in Figure 1 in the paper, and why doesn't the ECE improve in this case when we do sampling?

# %% [markdown]
# ***Brief Overview***
#
# ### Q1:
#
# Reason 1: The paper utilises a more principled Bayesian approximation (e.g., Laplace approximation) that explicitly models parameter uncertainty. Placing a Gaussian distribution over the network weights prevents predictions from being arbitrarily confident as we move further from the training data. In contrast, our notebook’s SGLD approach samples parameters without imposing a similarly structured representation of uncertainty. Consequently, the uncertainty in our plots is not as well controlled, resulting in broader confidence regions and residual overconfidence away from the data.
#
# Reason 2: The paper’s results are founded on carefully chosen architectures, priors, and hyperparameters that yield well-behaved uncertainty patterns. Their theoretical findings (e.g., bounding confidence far from data points) depend on a thoughtful setup. We utilised a simpler model in our coursework notebook and did not implement such tuning or advanced approximations. As a result, the uncertainty illustrated here appears more overconfident compared to the well-calibrated uncertainty displayed in Figure 1 of the paper.
#
# ### Q2:
# Temperature scaling merely rescales logits uniformly and does not address the root cause of overconfidence, predictions from ReLU networks grow unboundedly far from the training data. Since temperature scaling does not introduce genuine parameter uncertainty, it fails to mitigate overconfidence in unseen areas. As a result, ECE does not improve through temperature scaling or naive sampling alone. Without structurally modelling epistemic uncertainty (as the Bayesian methods in the paper do), the model remains overconfident, and calibration metrics such as ECE do not enhance.

# %% [markdown]
# *** More in Depth Answer ***
#
# ### Q1:
#
# ### Reason 1:
#
# Background:
#
# When comparing the graphs from this notebook to Figure 1 in the paper, the Bayesian plots in Figure 1 show high confidence only near the data points, while the notebook’s plots display broader confidence, except near the decision boundary. The notebook’s residual overconfidence in areas far from the data aligns with Theorem 2.1, which states:
#
# $$
# \delta \to \infty \quad \lim \, \text{softmax}(f(\delta x), i) = 1 \, \text{for some class } i \in \{1, \ldots, k\},
# $$
#
# ReLU networks trained with standard MAP approaches can produce arbitrarily high confidence as inputs $\delta x$ are scaled. This issue arises because MAP training does not account for parameter uncertainty, causing logits to grow unbounded. The failure to capture the parameter uncertainty could also be directly tied to the absence of epistemic uncertainty modelling.
#
# The paper improves this by introducing Gaussian approximations. Theorem 2.3 demonstrates that modelling all parameters $\theta$ as a Gaussian distribution, $N(\theta \mid \mu, \Sigma)$, limits confidence. Jacobian’s smallest singular value $s_{\text{min}}(J)$ and the covariance’s smallest eigenvalue $\lambda_{\text{min}}(\Sigma)$ ensure confidence remains finite, even for large $\delta$. A larger $s_{\text{min}}(J)$ enforces stricter bounds, while a larger $\lambda_{\text{min}}(\Sigma)$ increases uncertainty in regions without data.
#
# Theorem 2.4 simplifies this framework by focusing on last-layer weights, reducing computational complexity while preserving performance. By modelling last-layer weights $w$ as $N(w \mid \mu, \Sigma)$, confidence is governed by the mean weight vector norm $|\mu|$ and the smallest eigenvalue $\lambda_{\text{min}}(\Sigma)$. Larger $|\mu|$ increases confidence, while smaller $|\mu|$ reduces confidence, especially far from the data. Larger $\lambda_{\text{min}}(\Sigma)$ introduces more uncertainty, causing less confidence in regions without data. Theorem 2.4 bounds confidence as:
#
# $$
# \lim_{\delta \to \infty} \sigma(|z(\delta \mathbf{x})|) \leq \sigma\left(\frac{\|\mathbf{\mu}\|}{\sqrt{\pi / 8} \lambda_{\text{min}}(\Sigma)}\right).
# $$
#
# Reason:
#
# This approach efficiently models uncertainty while simplifying computation. These approximations impose strict confidence boundaries, ensuring predictions are not confident and are far from training data. Through modelling epistemic uncertainty, Gaussian approximations account for the model's lack of confidence for regions with sparse data. Unlike the SGLD-based notebook approach, which does not have uncertainty modelling, Gaussian approximations have terms like the covariance's smallest eigenvalue $\lambda_{\text{min}}(\Sigma)$ to control confidence levels effectively, stop overconfidence in regions with no data.
#
# In the notebook's SGLD-based approach, confidence is displayed even in locations without data and fails to decrease in areas away from the data. In contrast, the Bayesian methods in Figure 1 of the paper produce a more organised and sensible uncertainty. This shows that SGLD does not correctly handle uncertainty, as it needs to set clear boundaries for areas with little data. High confidence should be observed only near data points where the model has strong evidence. However, with the Gaussian method, uncertainty increases as inputs are further from the data, and the overconfidence issue is solved with ReLU. This will help keep the predictions accurate, providing a better management of overconfidence.
#
# ### Reason 2:
#
# Background:
#
# The Laplace Approximation provides practical advantages, particularly for pre-trained networks. Unlike Stochastic Gradient Langevin Dynamics (SGLD), which needs retraining and sampling during inference, the Laplace Approximation works directly on MAP-trained networks, making it more computationally efficient. By modelling the posterior $p(\theta \mid D)$ as $N(\theta \mid \mu, \Sigma)$, where $\mu$ is the MAP estimate, and $\Sigma$ comes from the Hessian of the negative log-posterior, this method links parameter uncertainty to the loss, ensuring reliable confidence even far from the data. This allows the Laplace approximation to model epistemic uncertainty and enables the model to recognise the limitations in regions that do not have sufficient data.
#
# Proposition 2.5 shows how prior variance $\sigma_0^2$ impacts confidence in Laplace-based models. A larger $\sigma_0^2$ reduces confidence far from training data, mitigating overconfidence. Proposition 2.5:
#
# $$
# \lim_{\sigma_0^2 \to \infty} \sigma(|z(x)|) \leq \sigma\left(\frac{|f_{\mu}(x)|}{1 + \sqrt{\pi / 8} \lambda_{\text{max}}(H) \|Jx\|^2}\right),
# $$
#
# Where $\lambda_{\text{max}}(H)$ is the largest eigenvalue of the Hessian, and $J$ is the Jacobian of the network output concerning inputs. This limit ensures confidence decreases far from the data, but a very large $\sigma_0^2$ can lower confidence within the data range, so careful tuning is needed. The covariance $\Sigma$ derived from the Hessian balances overconfidence mitigation and prediction accuracy.
#
# Reason:
#
# SGLD approximates the posterior by sampling across multiple modes, capturing broader uncertainty but lacking structured confidence control. This method explores the posterior, and its ensemble-like averaging improves uncertainty estimation by combining predictions from various samples. However, SGLD still shows overconfidence, especially in areas with little data, as it lacks explicit bounds to control uncertainty. This residual overconfidence comes from SGLD's failure to capture epistemic uncertainty. The Laplace Approximation uses covariance to capture epistemic uncertainty, showing the model's limitations in unexplored regions. As seen in the notebook's plots, this shows SGLD's weakness in providing accurate predictions far from the training data. With 50 variations in SGLD, the entire posterior is not fully represented, and the parameter space needs to be explored more.
#
# The Laplace Approximation focuses on local uncertainty around the MAP estimate, using $\Sigma$ to enforce tighter confidence bounds. As described in Theorems 2.3 and 2.4, this ensures confidence decays systematically as inputs move away from training data. Unlike SGLD, which diffuses uncertainty broadly, the Laplace Approximation produces structured uncertainty near data points, addressing overconfidence and balancing prediction accuracy with computational efficiency.
#
#
# ### Q2:
#
# **Calibration and Temperature Scaling**
#
# Temperature scaling is a post-processing technique that improves calibration by dividing logits by a temperature parameter $T$ before applying the softmax function. When $T < 1$, it reduces confidence everywhere. However, it only changes the intensity of the confidence distribution, not its overall shape. In Figure 1 of the paper, temperature scaling does not reduce overconfidence because the problem comes from the structural properties of ReLU networks, as explained in Theorem 2.1. These networks show extremely high confidence for inputs far from the training data because unbounded logits from MAP training fail to account for parameter uncertainty. Temperature scaling cannot set meaningful confidence limits far from the data or change the confidence distribution's shape, emphasising the importance of methods like Bayesian approaches. This limitation exists because temperature scaling ignores epistemic uncertainty.
#
# **Expected Calibration Error (ECE) and Sampling**
#
# The notebook's sampling does not improve ECE, which is due to SGLD's limitations. SGLD captures overall uncertainty but lacks clear confidence limits in areas without data. Like an ensemble, averaging predictions improves uncertainty estimates but still leaves some overconfidence, especially far from the training data. This disrupts confidence calibration and raises ECE values.
